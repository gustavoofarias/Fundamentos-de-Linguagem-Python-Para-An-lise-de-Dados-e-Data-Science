# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoofarias/Fundamentos-de-Linguagem-Python-Para-An-lise-de-Dados-e-Data-Science/blob/main/lab2_calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calculadora em Python

# %%
def calculadora(num1, num2):
    print('''Escolha a operação:
    1. Soma
    2. Subtração
    3. Divisão
    4. Multiplicação
    ''')

    escolha = int(input("Digite o número da operação: "))

    if escolha == 1:
        resultado = num1 + num2
        operacao = "soma"
    elif escolha == 2:
        resultado = num1 - num2
        operacao = "subtração"
    elif escolha == 3:
        resultado = num1 / num2
        operacao = "divisão"
    elif escolha == 4:
        resultado = num1 * num2
        operacao = "multiplicação"
    else:
        return "Operação inválida"

    return f"O resultado da {operacao} é: {resultado}"

# Exemplo de uso
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

print(calculadora(num1, num2))


calculo = calculadora(5,5)
print(calculo)
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 5
# Escolha a operação:
#     1. Soma
#     2. Subtração
#     3. Divisão
#     4. Multiplicação
#
# Digite o número da operação: 1
# O resultado da soma é: 10.0
# Escolha a operação:
#     1. Soma
#     2. Subtração
#     3. Divisão
#     4. Multiplicação
#
# Digite o número da operação: 21
# Operação inválida
